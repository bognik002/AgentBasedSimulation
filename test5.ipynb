# %%
from agents import ExchangeAgent, NoiseAgent, MarketMaker, ProbeTrader
from simulator import Simulator
import matplotlib.pyplot as plt

# %%
spread_initial = {'bid': 500, 'ask': 600}

# Initialize Exchange Agent
exchange = ExchangeAgent(spread_initial, depth=200)

# Initialize Traders
noise_agents = [NoiseAgent(exchange) for i in range(50)]
market_makers = [MarketMaker(exchange, 45, 100, 10) for j in range(2)]
probe_trader = ProbeTrader(exchange, 'ask', quantity_mean=50)

# Simulation
simulator = Simulator(exchange, noise_agents=noise_agents, market_makers=None,
                      probe_trader=None).fit(400, probe_start=100, probe_stop=200)
# Out:
# Market Initialization: 100%|██████████████████████████████████████████████████████| 199/199 [00:00<00:00, 14317.73it/s]
# Simulation: 100%|██████████████████████████████████████████████████████████████████| 400/400 [00:00<00:00, 2151.41it/s]

# %%
plt.figure(figsize=(10, 6))
simulator.plot_price()

# %%
plt.figure(figsize=(10, 6))
simulator.plot_volume()

# %%
plt.figure(figsize=(8, 6))
simulator.plot_states_heatmap()

# %%
spread_initial = {'bid': 500, 'ask': 600}

# Initialize Exchange Agent
exchange = ExchangeAgent(spread_initial, depth=500)

# Initialize Traders
noise_agents = [NoiseAgent(exchange) for i in range(50)]
market_makers = [MarketMaker(exchange, 45, 100, 10) for j in range(1)]
probe_trader = ProbeTrader(exchange, 'ask', quantity_mean=50)

# Simulation
simulator = Simulator(exchange, noise_agents=noise_agents, market_makers=market_makers,
                      probe_trader=None).fit(400, probe_start=100, probe_stop=200)
# Out:
# Market Initialization: 100%|███████████████████████████████████████████████████████| 499/499 [00:00<00:00, 3318.30it/s]
# Simulation: 100%|███████████████████████████████████████████████████████████████████| 400/400 [00:00<00:00, 480.01it/s]

# %%
plt.figure(figsize=(10, 6))
simulator.plot_price()

# %%
plt.figure(figsize=(10, 6))
simulator.plot_volume()

# %%
plt.figure(figsize=(8, 6))
simulator.plot_states_heatmap()

# %%
spread_initial = {'bid': 500, 'ask': 600}

# Initialize Exchange Agent
exchange = ExchangeAgent(spread_initial, depth=5000)

# Initialize Traders
noise_agents = [NoiseAgent(exchange) for i in range(50)]
market_makers = [MarketMaker(exchange, 45, 100, 10) for j in range(1)]
probe_trader = ProbeTrader(exchange, 'ask', quantity_mean=10)

# Simulation
simulator = Simulator(exchange, noise_agents=noise_agents, market_makers=None,
                      probe_trader=probe_trader).fit(400, probe_start=0)
# Out:
# Market Initialization: 100%|██████████████████████████████████████████████████████| 4999/4999 [00:14<00:00, 352.92it/s]
# Simulation: 100%|████████████████████████████████████████████████████████████████████| 400/400 [00:04<00:00, 83.60it/s]

# %%
plt.figure(figsize=(10, 6))
simulator.plot_price()

# %%
plt.figure(figsize=(10, 6))
simulator.plot_volume()

# %%
plt.figure(figsize=(8, 6))
simulator.plot_states_heatmap()

# %%
spread_initial = {'bid': 500, 'ask': 600}

# Initialize Exchange Agent
exchange = ExchangeAgent(spread_initial, depth=10000)

# Initialize Traders
noise_agents = [NoiseAgent(exchange) for i in range(50)]
market_makers = [MarketMaker(exchange, 45, 100, 10) for j in range(1)]
probe_trader = ProbeTrader(exchange, 'ask', quantity_mean=20)

# Simulation
simulator = Simulator(exchange, noise_agents=noise_agents, market_makers=market_makers,
                      probe_trader=probe_trader).fit(400, probe_start=0)
# Out:
# Market Initialization: 100%|██████████████████████████████████████████████████████| 9999/9999 [01:03<00:00, 158.68it/s]
# Simulation: 100%|████████████████████████████████████████████████████████████████████| 400/400 [00:10<00:00, 37.94it/s]

# %%
plt.figure(figsize=(10, 6))
simulator.plot_price()

# %%
plt.figure(figsize=(10, 6))
simulator.plot_volume()

# %%
plt.figure(figsize=(8, 6))
simulator.plot_states_heatmap()
