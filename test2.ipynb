# %%
import matplotlib.pyplot as plt
from random import seed

# %%
from agents import ExchangeAgent, NoiseAgent, MarketMaker, ProbeTrader
from simulator import Simulator


spread_initial = {'bid': 500, 'ask': 600}

# Initialize Exchange Agent
exchange = ExchangeAgent(spread_initial, depth=1000)

# Initialize Traders
noise_agents = [NoiseAgent(exchange) for i in range(100)]
market_makers = [MarketMaker(exchange, 45, 100, 10) for j in range(2)]
probe_trader = ProbeTrader(exchange, 'ask', quantity_mean=6)

# Simulation
simulator = Simulator(exchange, noise_agents=noise_agents, market_makers=None,
                      probe_trader=None).fit(500, nt_lag=0)
# Out:
# Market Initialization: 100%|███████████████████████████████████████████████████████| 999/999 [00:00<00:00, 4519.00it/s]
# Simulation: 100%|███████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 671.20it/s]

# %%
plt.figure(figsize=(10, 6))
simulator.plot_price(show_spread=False)

# %%
plt.figure(figsize=(10, 6))
simulator.plot_price(show_spread=True)

# %%
from agents import ExchangeAgent, NoiseAgent, MarketMaker, ProbeTrader
from simulator import Simulator


spread_initial = {'bid': 500, 'ask': 600}

# Initialize Exchange Agent
exchange = ExchangeAgent(spread_initial, depth=1000)

# Initialize Traders
noise_agents = [NoiseAgent(exchange) for i in range(100)]
market_makers = [MarketMaker(exchange, 45, 100, 10) for j in range(2)]
probe_trader = ProbeTrader(exchange, 'ask', quantity_mean=6)

# Simulation
simulator = Simulator(exchange, noise_agents=noise_agents, market_makers=None,
                      probe_trader=None).fit(500, nt_lag=5)
# Out:
# Market Initialization: 100%|███████████████████████████████████████████████████████| 999/999 [00:00<00:00, 5472.06it/s]
# Simulation: 100%|███████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 739.53it/s]

# %%
plt.figure(figsize=(10, 6))
simulator.plot_price(show_spread=False)

# %%
from agents import ExchangeAgent, NoiseAgent, MarketMaker, ProbeTrader
from simulator import Simulator


spread_initial = {'bid': 500, 'ask': 600}

# Initialize Exchange Agent
exchange = ExchangeAgent(spread_initial, depth=1000)

# Initialize Traders
noise_agents = [NoiseAgent(exchange) for i in range(100)]
market_makers = [MarketMaker(exchange, 45, 100, 10) for j in range(2)]
probe_trader = ProbeTrader(exchange, 'ask', quantity_mean=6)

# Simulation
simulator = Simulator(exchange, noise_agents=noise_agents, market_makers=None,
                      probe_trader=None).fit(500, nt_lag=20)
# Out:
# Market Initialization: 100%|███████████████████████████████████████████████████████| 999/999 [00:00<00:00, 5520.01it/s]
# Simulation: 100%|███████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 771.51it/s]

# %%
plt.figure(figsize=(10, 6))
simulator.plot_price(show_spread=False)

# %%
plt.figure(figsize=(10, 6))
simulator.plot_volume()
